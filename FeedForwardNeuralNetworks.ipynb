# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# Activation Functions

# %%
# Heaviside step function 

def heavyside(x):
    if (x >= 0):
        return 1
    else :
        return 0
        
# Rectified error Linear Unit function

def relu(x):
    return max(0,x)

# Sigmoid function

def activation_sigmoid(t):
        return 1/(1+np.exp(-t))

def sigmoid(x):
    return 1/(1+np.exp(-x))

def softmax(t):
    return np.exp(t)/np.sum(np.exp(t))

# Gassian error Linear Unit GeLU function

# %% [markdown]
# Neural Network

# %%
# Dataset
data = load_diabetes()
X = data['data']
y = data['target']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
class NeuralNetwork :

    def __init__(self):
        self.layers_wieghts = []
        self.layers_bias = []
        self.layers_activations = []  

    def activation_sigmoid(self, t):
        return 1/(1+np.exp(-t))

    def activation_sigmoid_derivative(self, t):
        return np.exp(-t)/(1+np.exp(-t))**2
    
    def activation_relu(self,t):
        return np.maximum(0,t)
    
    def activation_relu_derivative(self,t):
        return np.where(t <= 0, 0, 1)

    def activation_identity(self,t):
        return t
    
    def activation_identity_derivative(self,t):
        return 1

    def loss(self, X_train, y_train):
        y_hat = self.out(X_train)
        return mean_squared_error(y_hat, y_train)

    def loss_for_a_sample(self,x,y):
        y_hat = self.out(x)
        return np.mean((y_hat-y)**2)
                                  
    def integrate_layer(self,layer_index, x):
        out = self.layers_wieghts[layer_index]@x + self.layers_bias[layer_index]
        if (self.layers_activations[layer_index] == 's'):
            return  self.activation_sigmoid(out)
        elif (self.layers_activations[layer_index] == 'r'):
            return  self.activation_relu(out)
        elif (self.layers_activations[layer_index] == 'i'):
            return  self.activation_identity(out)
    
    def add_layer(self, layer_size, activation):

        if len(self.layers_activations) == 0:
            self.layers_wieghts.append(np.random.rand(layer_size, layer_size))
            self.layers_bias.append(np.random.rand(layer_size))
            self.layers_activations.append(activation)
        else :
            self.layers_wieghts.append(np.random.rand(layer_size, len(self.layers_bias[-1])))
            self.layers_bias.append(np.random.rand(layer_size))
            self.layers_activations.append(activation)
        
    def update_weights(self, layer_index, delta_w):
        self.layers_wieghts[layer_index]  = self.layers_wieghts[layer_index]  + delta_w

    def update_bias(self, layer_index, delta_b):
        self.layers_bias[layer_index]  = self.layers_bias[layer_index] + delta_b 

    def delete_layer(self):
        if len(self.layers) > 1:
            self.layers.pop()
        else :
            print("No Hidden Layers to delete")

    def derivative_of_activation_step(self,E, layer_index):
        if self.layers_activations[layer_index] == 's':
            return self.activation_sigmoid_derivative(E)
        elif self.layers_activations[layer_index] == 'r':
            return self.activation_relu_derivative(E)
        elif self.layers_activations[layer_index] == 'i':
            return self.activation_identity_derivative(E)

    def backward(self, X_, y_, alpha):
        activations = self.get_activations(X_)
        l = len(self.layers_bias)

        # Initiating with Output Layer
        E_d = activations[l-1] - y_
        E_d = E_d*self.derivative_of_activation_step(E_d, l-1)
        delta_w = -(alpha/len(E_d))*2* E_d @ activations[l-2].T.reshape(-1, len(activations[l-2]))
        delta_b = -(alpha/len(E_d))*2* E_d
        delta_a_l = -alpha*2*E_d @ self.layers_wieghts[l-1]
        delta_a_l = delta_a_l*self.derivative_of_activation_step(delta_a_l,l-1)
        self.update_weights(l-1, delta_w)
        self.update_bias(l-1, delta_b)
        # print(activations)
        # print("\n")
        
        # Hidden Layers
        for i in range(l-2,0,-1):
            delta_w = -((alpha/len(delta_a_l))*2* delta_a_l).reshape(len(delta_a_l),1) @ activations[i-1].T.reshape(-1, len(activations[i-1]))
            delta_b = -(alpha/len(delta_a_l))*2* delta_a_l
            self.update_weights(i, delta_w)
            self.update_bias(i, delta_b)
            delta_a_l = -(alpha/len(delta_a_l))*2*delta_a_l @ self.layers_wieghts[i]
            delta_a_l = delta_a_l*self.derivative_of_activation_step(delta_a_l,i)
        
        # Input Layer
        delta_w = -(alpha/len(delta_a_l))*2* delta_a_l.reshape(len(delta_a_l),1) @ X_.T.reshape(-1,len(X_))
        delta_b = -(alpha/len(delta_a_l))*2* delta_a_l
        self.update_weights(0, delta_w)
        self.update_bias(0, delta_b)
    
    def get_activations(self, X_):
        l = len(self.layers_bias)
        activations = []
        previous_out = self.integrate_layer(0, X_).copy()
        activations.append(previous_out)
        for i in range(1,l):
            current_out = self.integrate_layer(i,previous_out).copy()
            previous_out = current_out.copy()
            activations.append(previous_out)
        return activations

    def forward(self, X_):
        l = len(self.layers_bias)
        previous_out = self.integrate_layer(0, X_).copy()
        for i in range(1,l):
            current_out = self.integrate_layer(i,previous_out).copy()
            previous_out = current_out.copy()
        return previous_out
    
    def train(self,alpha, X_train, y_train):
        max_epochs = 1000
        for e in range(max_epochs):
            # out = self.predict(X_train)
            # print(mean_squared_error(out,y_train),out[0])
            for i in range(len(X_train)):
                self.backward(X_train[i],y_train[i],alpha)
            
    def predict(self, X_test):
        n = len(X_test)
        m = len(self.layers_bias[-1])
        prediction = np.empty((n,m))
        for i in range(n):
            out = self.forward(X_test[i])
            for j in range(m):
                prediction[i][j] = out[j]
        return prediction

# %%
nn = NeuralNetwork()
nn.add_layer(10,'r')
nn.add_layer(1,'i')

# %%
nn.forward(X_train[4])
# Out:
# array([2.53825609])

# %%
nn.train(0.0001, X_train, y_train)

# %%
y_hat = nn.predict(X_test)

# %%
# Plotting
sr = np.arange(len(y_test))
plt.plot(sr,y_test)
plt.plot(sr,y_hat)
plt.show()

# %%
mean_squared_error(y_hat, y_test)
# Out:
# 5101.457453919897

# %% [markdown]
# PyTorch Implementation

# %%
# Dataset
data = load_diabetes()
X = data['data']
y = data['target']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).reshape(-1, 1)
X_test= torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32).reshape(-1, 1)

# Model
model = nn.Sequential(
    nn.Linear(10, 12),
    nn.ReLU(),
    nn.Linear(12, 8),
    nn.ReLU(),
    nn.Linear(8, 1),
)
print(model)
 
# train the model
loss_fn   = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=0.001)
 
n_epochs = 100
batch_size = 10
 
for epoch in range(n_epochs):
    for i in range(0, len(X_train), batch_size):
        Xbatch = X_train[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y_train[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, current loss {loss}')
# Out:
# Sequential(
#   (0): Linear(in_features=10, out_features=12, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=12, out_features=8, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=8, out_features=1, bias=True)
# )
# Finished epoch 0, current loss 32948.55859375
# Finished epoch 1, current loss 32870.33984375
# Finished epoch 2, current loss 32749.263671875
# Finished epoch 3, current loss 32561.150390625
# Finished epoch 4, current loss 32278.111328125
# Finished epoch 5, current loss 31873.373046875
# Finished epoch 6, current loss 31323.755859375
# Finished epoch 7, current loss 30610.103515625
# Finished epoch 8, current loss 29718.380859375
# Finished epoch 9, current loss 28640.810546875
# Finished epoch 10, current loss 27376.869140625
# Finished epoch 11, current loss 25934.0546875
# Finished epoch 12, current loss 24328.296875
# Finished epoch 13, current loss 22583.947265625
# Finished epoch 14, current loss 20733.326171875
# Finished epoch 15, current loss 18815.64453125
# Finished epoch 16, current loss 16875.333984375
# Finished epoch 17, current loss 14959.7451171875
# Finished epoch 18, current loss 13116.2890625
# Finished epoch 19, current loss 11389.2236328125
# Finished epoch 20, current loss 9816.3154296875
# Finished epoch 21, current loss 8425.8359375
# Finished epoch 22, current loss 7234.35205078125
# Finished epoch 23, current loss 6245.7578125
# Finished epoch 24, current loss 5451.86279296875
# Finished epoch 25, current loss 4834.54248046875
# Finished epoch 26, current loss 4369.02978515625
# Finished epoch 27, current loss 4027.6552734375
# Finished epoch 28, current loss 3783.247314453125
# Finished epoch 29, current loss 3611.5791015625
# Finished epoch 30, current loss 3492.667236328125
# Finished epoch 31, current loss 3411.008544921875
# Finished epoch 32, current loss 3355.163818359375
# Finished epoch 33, current loss 3316.9951171875
# Finished epoch 34, current loss 3290.868896484375
# Finished epoch 35, current loss 3272.939697265625
# Finished epoch 36, current loss 3260.6123046875
# Finished epoch 37, current loss 3252.141845703125
# Finished epoch 38, current loss 3246.3486328125
# Finished epoch 39, current loss 3242.440673828125
# Finished epoch 40, current loss 3239.875
# Finished epoch 41, current loss 3238.2880859375
# Finished epoch 42, current loss 3237.424072265625
# Finished epoch 43, current loss 3237.11328125
# Finished epoch 44, current loss 3237.2333984375
# Finished epoch 45, current loss 3237.701416015625
# Finished epoch 46, current loss 3238.4599609375
# Finished epoch 47, current loss 3239.4638671875
# Finished epoch 48, current loss 3240.683349609375
# Finished epoch 49, current loss 3242.092529296875
# Finished epoch 50, current loss 3243.674560546875
# Finished epoch 51, current loss 3245.413818359375
# Finished epoch 52, current loss 3247.297119140625
# Finished epoch 53, current loss 3249.314453125
# Finished epoch 54, current loss 3251.455078125
# Finished epoch 55, current loss 3253.7109375
# Finished epoch 56, current loss 3256.072998046875
# Finished epoch 57, current loss 3258.532958984375
# Finished epoch 58, current loss 3261.0849609375
# Finished epoch 59, current loss 3263.720947265625
# Finished epoch 60, current loss 3266.436279296875
# Finished epoch 61, current loss 3269.220703125
# Finished epoch 62, current loss 3272.071044921875
# Finished epoch 63, current loss 3274.979736328125
# Finished epoch 64, current loss 3277.941162109375
# Finished epoch 65, current loss 3280.951171875
# Finished epoch 66, current loss 3284.002685546875
# Finished epoch 67, current loss 3287.090087890625
# Finished epoch 68, current loss 3290.207763671875
# Finished epoch 69, current loss 3293.353271484375
# Finished epoch 70, current loss 3296.519775390625
# Finished epoch 71, current loss 3299.7021484375
# Finished epoch 72, current loss 3302.895263671875
# Finished epoch 73, current loss 3306.096435546875
# Finished epoch 74, current loss 3309.300537109375
# Finished epoch 75, current loss 3312.503173828125
# Finished epoch 76, current loss 3315.699462890625
# Finished epoch 77, current loss 3318.887939453125
# Finished epoch 78, current loss 3322.061279296875
# Finished epoch 79, current loss 3325.218994140625
# Finished epoch 80, current loss 3328.356201171875
# Finished epoch 81, current loss 3331.468994140625
# Finished epoch 82, current loss 3334.555419921875
# Finished epoch 83, current loss 3337.609619140625
# Finished epoch 84, current loss 3340.633056640625
# Finished epoch 85, current loss 3343.62109375
# Finished epoch 86, current loss 3346.568359375
# Finished epoch 87, current loss 3349.4755859375
# Finished epoch 88, current loss 3352.341552734375
# Finished epoch 89, current loss 3355.159912109375
# Finished epoch 90, current loss 3357.931396484375
# Finished epoch 91, current loss 3360.6533203125
# Finished epoch 92, current loss 3363.324462890625
# Finished epoch 93, current loss 3365.9443359375
# Finished epoch 94, current loss 3368.509033203125
# Finished epoch 95, current loss 3371.016845703125
# Finished epoch 96, current loss 3373.470703125
# Finished epoch 97, current loss 3375.8671875
# Finished epoch 98, current loss 3378.203369140625
# Finished epoch 99, current loss 3380.482421875

# %%
y_hat = model(X_test)

# %%
# Plotting
sr = np.arange(len(y_test))
plt.plot(sr, np.array(y_test))
plt.plot(sr,y_hat.detach().numpy())
plt.show()
